# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df_json = pd.read_csv("logs/20260409_071506_json_decoder_stv.py.csv")
print(f'My log file has {len(df_json)} number of rows')
df_ipv4 = pd.read_csv("logs/20260409_080550_linux-ipv4-parser.csv")
print(f'My log file has {len(df_ipv4)} number of rows')
df_ipv6 = pd.read_csv("logs/20260409_115423_linux-ipv6-parser.csv")
print(f'My log file has {len(df_ipv6)} number of rows')
df_cidrize = pd.read_csv("logs/20260409_092927_linux-cidrize-runner.csv")
print(f'My log file has {len(df_cidrize)} number of rows')
# df_ipv6 = pd.read_csv("20260409_092927_linux-cidrize-runner")
# print(f'My ledger file has {len(df_ipv6)} number of rows')
# Out:
# My log file has 5000 number of rows
# My log file has 5000 number of rows
# My log file has 5000 number of rows
# My log file has 5000 number of rows

# %%
display(df_json)
# Out:
#        timestamp  iteration  is_interesting    tier        reason  \
# 0     1775690107          0               1  tier_2  new_coverage
# 1     1775690107          1               1  tier_2  new_coverage
# 2     1775690107          2               1  tier_2  new_coverage
# 3     1775690108          3               1  tier_2  new_coverage
# 4     1775690108          4               1  tier_2  new_coverage
# ...          ...        ...             ...     ...           ...
# 4995  1775691694       4995               0     NaN           NaN
# 4996  1775691694       4996               0     NaN           NaN
# 4997  1775691695       4997               0     NaN           NaN
# 4998  1775691695       4998               0     NaN           NaN
# 4999  1775691695       4999               0     NaN           NaN
#
#                         op_name  \
# 0                        warmup
# 1                        warmup
# 2                        warmup
# 3                        warmup
# 4                        warmup
# ...                         ...
# 4995             mut_dictionary
# 4996  mut_string_numeric_jitter
# 4997                 mut_splice
# 4998           mut_delete_chunk
# 4999             mut_arithmetic
#
#                                               seed_text  \
# 0     {"k0":-188,"k1":928,"k2":464,"k3":-594,"k4":-8...
# 1     {"k0":-541,"k1":331,"k2":-860,"k3":599,"k4":96...
# 2                                                    {}
# 3     {"k0":-792,"k1":427,"k2":582,"k3":-383,"k4":74...
# 4     {"k0":-965,"k1":-810,"k2":-398,"k3":-547,"k4":...
# ...                                                 ...
# 4995                        -25,"k2":7,"k?":5,"k5":-83}
# 4996          {"k0""\u2764","escape":"line\nnext---"  }
# 4997  {"k0":649,"k1":-753,*k\t\t2":630,"k3":15\t\t\t...
# 4998  {"k5":414,�k1":-O5,"k2":32,"k3":457,"k4":5,"k...
# 4999  {"k0":-188,"k1":928,"k2":464,"k3":-594,"k4":-8...
#
#                                            mutated_text  \
# 0     {"k0":-188,"k1":928,"k2":464,"k3":-594,"k4":-8...
# 1     {"k0":-541,"k1":331,"k2":-860,"k3":599,"k4":96...
# 2                                                    {}
# 3     {"k0":-792,"k1":427,"k2":582,"k3":-383,"k4":74...
# 4     {"k0":-965,"k1":-810,"k2":-398,"k3":-547,"k4":...
# ...                                                 ...
# 4995                       -25,"k2":7,"k?":5,"k5":-:83}
# 4996          {"k6""\u2764","escape":"line\nnext---"  }
# 4997  {"k0":649,"k1":-753,*k\t\t2":630,"k3":15\t\t\t...
# 4998  {"k5":414,�k1":-O5,"k2":32,"k3":457,"4":5,"k5...
# 4999  {"k0":-188,"k1":928,"k2":464,"k3"6-594,"k4":-8...
#
#                                                seed_b64  \
# 0     eyJrMCI6LTE4OCwiazEiOjkyOCwiazIiOjQ2NCwiazMiOi...
# 1     eyJrMCI6LTU0MSwiazEiOjMzMSwiazIiOi04NjAsImszIj...
# 2                                                  e30=
# 3     eyJrMCI6LTc5MiwiazEiOjQyNywiazIiOjU4MiwiazMiOi...
# 4     eyJrMCI6LTk2NSwiazEiOi04MTAsImsyIjotMzk4LCJrMy...
# ...                                                 ...
# 4995               LTI1LCJrMiI6Nywiaz8iOjUsIms1IjotODN9
# 4996  eyJrMCIiXHUyNzY0IiwiZXNjYXBlIjoibGluZVxubmV4dC...
# 4997  eyJrMCI6NjQ5LCJrMSI6LTc1MywqawkJMiI6NjMwLCJrMy...
# 4998  eyJrNSI6NDE0LKJrMSI6LU81LCJrMiI6MxIyLCJrMyI6ND...
# 4999  eyJrMCI6LTE4OCwiazEiOjkyOCwiazIiOjQ2NCwiazMiOi...
#
#                                             mutated_b64  ... timed_out  \
# 0     eyJrMCI6LTE4OCwiazEiOjkyOCwiazIiOjQ2NCwiazMiOi...  ...     False
# 1     eyJrMCI6LTU0MSwiazEiOjMzMSwiazIiOi04NjAsImszIj...  ...     False
# 2                                                  e30=  ...     False
# 3     eyJrMCI6LTc5MiwiazEiOjQyNywiazIiOjU4MiwiazMiOi...  ...     False
# 4     eyJrMCI6LTk2NSwiazEiOi04MTAsImsyIjotMzk4LCJrMy...  ...     False
# ...                                                 ...  ...       ...
# 4995           LTI1LCJrMiI6Nywiaz8iOjUsIms1IjotOjgzfQ==  ...     False
# 4996  eyJrNiIiXHUyNzY0IiwiZXNjYXBlIjoibGluZVxubmV4dC...  ...     False
# 4997  eyJrMCI6NjQ5LCJrMSI6LTc1MywqawkJMiI6NjMwLCJrMy...  ...     False
# 4998  eyJrNSI6NDE0LKJrMSI6LU81LCJrMiI6MxIyLCJrMyI6ND...  ...     False
# 4999  eyJrMCI6LTE4OCwiazEiOjkyOCwiazIiOjQ2NCwiazMiNi...  ...     False
#
#       generation_time_sec  elapsed_sec  \
# 0                0.000000     0.295692
# 1                0.000000     0.285385
# 2                0.000000     0.280069
# 3                0.000000     0.324978
# 4                0.000000     0.316719
# ...                   ...          ...
# 4995             0.000272     0.312785
# 4996             0.000299     0.307929
# 4997             0.000439     0.307576
# 4998             0.000382     0.321532
# 4999             0.000269     0.297619
#
#                                                 command    bug_type  \
# 0     python3 ../json-decoder/json_decoder_stv.py --...         NaN
# 1     python3 ../json-decoder/json_decoder_stv.py --...         NaN
# 2     python3 ../json-decoder/json_decoder_stv.py --...         NaN
# 3     python3 ../json-decoder/json_decoder_stv.py --...         NaN
# 4     python3 ../json-decoder/json_decoder_stv.py --...         NaN
# ...                                                 ...         ...
# 4995  python3 ../json-decoder/json_decoder_stv.py --...         NaN
# 4996  python3 ../json-decoder/json_decoder_stv.py --...  invalidity
# 4997  python3 ../json-decoder/json_decoder_stv.py --...  invalidity
# 4998  python3 ../json-decoder/json_decoder_stv.py --...  invalidity
# 4999  python3 ../json-decoder/json_decoder_stv.py --...  invalidity
#
#                                    exception  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# ...                                      ...
# 4995                                     NaN
# 4996  buggy_json.decoder_stv.JSONDecodeError
# 4997  buggy_json.decoder_stv.JSONDecodeError
# 4998  buggy_json.decoder_stv.JSONDecodeError
# 4999  buggy_json.decoder_stv.JSONDecodeError
#
#                                                 message  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 4995                                                NaN
# 4996  Expecting ':' delimiter: line 1 column 6 (char 5)
# 4997  Expecting property name enclosed in double quo...
# 4998  Expecting property name enclosed in double quo...
# 4999  Expecting ':' delimiter: line 1 column 34 (cha...
#
#                                                    file   line  \
# 0                                                   NaN    NaN
# 1                                                   NaN    NaN
# 2                                                   NaN    NaN
# 3                                                   NaN    NaN
# 4                                                   NaN    NaN
# ...                                                 ...    ...
# 4995                                                NaN    NaN
# 4996  /home/royce/software_testing/json-decoder/bugg...  196.0
# 4997  /home/royce/software_testing/json-decoder/bugg...  232.0
# 4998  /home/royce/software_testing/json-decoder/bugg...  232.0
# 4999  /home/royce/software_testing/json-decoder/bugg...  196.0
#
#                             input_hash
# 0     f9e37cc1f6f5b42956fb58e1a146feae
# 1     f19115a672eba1a0c877b276f2b6c329
# 2     99914b932bd37a50b983c5e7c90ae93b
# 3     ef7a37d19ae3c460846e10fd04ef835b
# 4     8498f7be2f6e418e8015c6c7438457f9
# ...                                ...
# 4995  efc02baf1f73ce53b3e05806b8ec3ff0
# 4996  35bf7e67b1c4f65f3b7f31627c11671b
# 4997  e86e6045dfed0093705a635556128ca3
# 4998  aaf312f4fa14cb58013ebbb56cb95c04
# 4999  bf0843df4f894cfa367670a049704c74
#
# [5000 rows x 22 columns]

# %%
df_json.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 22 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   timestamp            5000 non-null   int64
#  1   iteration            5000 non-null   int64
#  2   is_interesting       5000 non-null   int64
#  3   tier                 2138 non-null   str
#  4   reason               2138 non-null   str
#  5   op_name              5000 non-null   str
#  6   seed_text            5000 non-null   str
#  7   mutated_text         4996 non-null   str
#  8   seed_b64             5000 non-null   str
#  9   mutated_b64          4998 non-null   str
#  10  status               5000 non-null   str
#  11  exit_code            5000 non-null   int64
#  12  timed_out            5000 non-null   bool
#  13  generation_time_sec  5000 non-null   float64
#  14  elapsed_sec          5000 non-null   float64
#  15  command              5000 non-null   str
#  16  bug_type             4216 non-null   str
#  17  exception            4216 non-null   str
#  18  message              4216 non-null   str
#  19  file                 4216 non-null   str
#  20  line                 4216 non-null   float64
#  21  input_hash           5000 non-null   str
# dtypes: bool(1), float64(3), int64(4), str(14)
# memory usage: 825.3 KB

# %% [markdown]
# Avg execution time for SUT

# %%
avg_exec_time_json = df_json["elapsed_sec"].mean()
avg_exec_time_cidrize = df_cidrize["elapsed_sec"].mean()
avg_exec_time_ipv4 = df_ipv4["elapsed_sec"].mean()
avg_exec_time_ipv6 = df_ipv6["elapsed_sec"].mean()
print(f"Avg execution time (json decoder): {avg_exec_time_json:.6f} sec")
print(f"Avg execution time (cidrize): {avg_exec_time_cidrize:.6f} sec")
print(f"Avg execution time (ipv4): {avg_exec_time_ipv4:.6f} sec")
print(f"Avg execution time (ipv6): {avg_exec_time_ipv6:.6f} sec")
# Out:
# Avg execution time (json decoder): 0.316495 sec
# Avg execution time (cidrize): 1.019357 sec
# Avg execution time (ipv4): 0.959458 sec
# Avg execution time (ipv6): 1.019874 sec

# %%
# copy df without warm-up rows
df_no_warmup_json = df_json[df_json["op_name"] != "warm_up"].copy()
df_no_warmup_cidrize= df_cidrize[df_cidrize["op_name"] != "warm_up"].copy()
df_no_warmup_ipv4 = df_ipv4[df_ipv4["op_name"] != "warm_up"].copy()
df_no_warmup_ipv6 = df_ipv6[df_ipv6["op_name"] != "warm_up"].copy()

# averages on filtered df
avg_gen_time_no_warmup_json = df_no_warmup_json["generation_time_sec"].mean()
avg_elapsed_no_warmup_json = df_no_warmup_json["elapsed_sec"].mean()
avg_gen_time_no_warmup_cidrize = df_no_warmup_cidrize["generation_time_sec"].mean()
avg_elapsed_no_warmup_cidrize = df_no_warmup_cidrize["elapsed_sec"].mean()
avg_gen_time_no_warmup_ipv4 = df_no_warmup_ipv4["generation_time_sec"].mean()
avg_elapsed_no_warmup_ipv4 = df_no_warmup_ipv4["elapsed_sec"].mean()
avg_gen_time_no_warmup_ipv6 = df_no_warmup_ipv6["generation_time_sec"].mean()
avg_elapsed_no_warmup_ipv6 = df_no_warmup_ipv6["elapsed_sec"].mean()

print("WITHOUT WARM-UP")
print(f"Avg generation_time_sec json: {avg_gen_time_no_warmup_json:.6f}")
# print(f"Avg elapsed_sec json:         {avg_elapsed_no_warmup_json:.6f}")
print(f"Avg generation_time_sec cidrize: {avg_gen_time_no_warmup_cidrize:.6f}")
# print(f"Avg elapsed_sec cidrize:         {avg_elapsed_no_warmup_cidrize:.6f}")
print(f"Avg generation_time_sec ipv4: {avg_gen_time_no_warmup_ipv4:.6f}")
# print(f"Avg elapsed_sec ipv4:         {avg_elapsed_no_warmup_ipv4:.6f}")
print(f"Avg generation_time_sec ipv6: {avg_gen_time_no_warmup_ipv6:.6f}")
# print(f"Avg elapsed_sec ipv6:         {avg_elapsed_no_warmup_ipv6:.6f}")
# Out:
# WITHOUT WARM-UP
# Avg generation_time_sec json: 0.000229
# Avg generation_time_sec cidrize: 0.000222
# Avg generation_time_sec ipv4: 0.000209
# Avg generation_time_sec ipv6: 0.000223

# %% [markdown]
# Interesting case vs test cases

# %%
dfs = [df_json, df_cidrize, df_ipv4, df_ipv6]  # your different dataframes
titles = ["JSON", "Cidrize", "Ipv4", "Ipv6"]

fig, axes = plt.subplots(1, 4, figsize=(18, 5))

for i, df in enumerate(dfs):
    df['cumulative_interesting'] = df['is_interesting'].cumsum()
    
    axes[i].plot(df['iteration'], df['cumulative_interesting'], linewidth=2)
    axes[i].set_title(titles[i])
    axes[i].set_xlabel('Iteration')
    axes[i].set_ylabel('No. of Interesting')
    axes[i].grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# Unique bugs vs Iteration USING LEDGER

# %%
# Number of unique bug types
print("JSON 5000 iteration")
bug_counts = df_json['bug_type'].value_counts()
print(bug_counts)
print("------------------------")
# Number of unique exceptions
exception_counts = df_json['exception'].value_counts()
print(exception_counts)
print("========================")
# Out:
# JSON 5000 iteration
# bug_type
# invalidity    4216
# Name: count, dtype: int64
# ------------------------
# exception
# buggy_json.decoder_stv.JSONDecodeError    4182
# InvalidityBug                               34
# Name: count, dtype: int64
# ========================

# %%
print("Cidrize 5000 iteration")
bug_counts = df_cidrize['bug_type'].value_counts()
print(bug_counts)
print("------------------------")
exception_counts = df_cidrize['exception'].value_counts()
print(exception_counts)
print("========================")
# Out:
# Cidrize 5000 iteration
# bug_type
# other         4730
# invalidity       9
# validity         1
# Name: count, dtype: int64
# ------------------------
# exception
# netaddr.core.AddrFormatError                        4688
# buggy_cidrize.cidrize_stv.ReliabilityBug              42
# buggy_cidrize.cidrize_stv.InvalidCidrFormatError       9
# ValidityBug                                            1
# Name: count, dtype: int64
# ========================

# %%
print("Ipv4 5000 iteration")
bug_counts = df_ipv4['bug_type'].value_counts()
print(bug_counts)
print("------------------------")
exception_counts = df_ipv4['exception'].value_counts()
print(exception_counts)
print("========================")
# Out:
# Ipv4 5000 iteration
# bug_type
# validity      2674
# invalidity    1815
# functional      48
# Name: count, dtype: int64
# ------------------------
# exception
# ParseException    3732
# InvalidityBug      757
# FunctionalBug       48
# Name: count, dtype: int64
# ========================

# %%
print("Ipv6 5000 iteration")
bug_counts = df_ipv6['bug_type'].value_counts()
print(bug_counts)
print("------------------------")
exception_counts = df_ipv6['exception'].value_counts()
print(exception_counts)
print("========================")
# Out:
# Ipv6 5000 iteration
# bug_type
# invalidity    4133
# other          613
# validity        10
# Name: count, dtype: int64
# ------------------------
# exception
# ParseException                             3945
# buggy_ipyparse.ipv6_mstv.ReliabilityBug     613
# InvalidityBug                               198
# Name: count, dtype: int64
# ========================

# %%
df_json_ledger = pd.read_csv("logs/bug_repro_ledger_5000_json.csv")
print(f'My ledger file has {len(df_json_ledger)} number of rows')
df_ipv4_ledger = pd.read_csv("logs/bug_repro_ledger_5000_ipv4.csv")
print(f'My ledger file has {len(df_ipv4_ledger)} number of rows')
df_cidrize_ledger = pd.read_csv("logs/bug_repro_ledger_5000_cidrize.csv")
print(f'My ledger file has {len(df_cidrize_ledger)} number of rows')
df_ipv6_ledger = pd.read_csv("logs/bug_repro_ledger_5000_ipv6.csv")
print(f'My ledger file has {len(df_ipv6_ledger)} number of rows')
# Out:
# My ledger file has 636 number of rows
# My ledger file has 265 number of rows
# My ledger file has 4349 number of rows
# My ledger file has 7 number of rows

# %%
dfs = [
    (df_json_ledger, "JSON"),
    (df_ipv4_ledger, "IPv4"),
    (df_cidrize_ledger, "cidrize"),
    (df_ipv6_ledger, "IPv6")
]

fig, axes = plt.subplots(1, 4, figsize=(18, 5))

max_elapsed = 0
prepared = []

for df, title in dfs:
    df = df.copy()
    df["timestamp"] = pd.to_datetime(df["timestamp"], unit="s")
    df = df.sort_values("timestamp").reset_index(drop=True)
    df["Unique Crashes"] = range(1, len(df) + 1)
    df["elapsed_sec"] = (df["timestamp"] - df["timestamp"].min()).dt.total_seconds()
    df["elapsed_min"] = df["elapsed_sec"] / 60
    max_elapsed = max(max_elapsed, df["elapsed_min"].max())
    prepared.append((df, title))

for i, (df, title) in enumerate(prepared):
    coeffs = np.polyfit(df["elapsed_min"], df["Unique Crashes"], 2)
    trendline = np.polyval(coeffs, df["elapsed_min"])

    axes[i].plot(df["elapsed_min"], df["Unique Crashes"], marker="o", linestyle="-", label="Actual")
    axes[i].plot(df["elapsed_min"], trendline, linestyle="--", label="Trendline")

    axes[i].set_title(f"{title} Crashes")
    axes[i].set_xlabel("Minutes since first unique crash")
    axes[i].set_ylabel("Unique Crashes")
    axes[i].set_xlim(0, max_elapsed)
    axes[i].grid(True)
    axes[i].legend()

plt.tight_layout()
plt.show()

# %%
dfs = [
    (df_json, "JSON"),
    (df_ipv4, "IPv4"),
    (df_ipv6, "IPv6"),
    (df_cidrize, "cidrize")
]

fig, axes = plt.subplots(1, 4, figsize=(24, 5))

max_elapsed = 0
prepared = []

for df, title in dfs:
    df = df.copy()

    # Convert timestamp from unix seconds
    df["timestamp"] = pd.to_datetime(df["timestamp"], unit="s")

    # Sort by time
    df = df.sort_values("timestamp").reset_index(drop=True)

    # Keep all 5000 rows, but only define bug signatures where bug info exists
    has_bug = (
        df["bug_type"].notna() &
        df["exception"].notna() &
        df["line"].notna()
    )

    df["bug_signature"] = None
    df.loc[has_bug, "bug_signature"] = (
        df.loc[has_bug, "bug_type"].astype(str).str.strip() + " | " +
        df.loc[has_bug, "exception"].astype(str).str.strip() + " | " +
        df.loc[has_bug, "line"].astype(str).str.strip()
    )

    # Mark only the FIRST occurrence of each unique bug
    df["is_new_bug"] = False
    df.loc[has_bug, "is_new_bug"] = ~df.loc[has_bug, "bug_signature"].duplicated()

    # Cumulative count of unique crashes across all 5000 rows
    df["Unique Crashes"] = df["is_new_bug"].cumsum()

    # Elapsed time in minutes from start of campaign
    df["elapsed_min"] = (
        df["timestamp"] - df["timestamp"].min()
    ).dt.total_seconds() / 60

    max_elapsed = max(max_elapsed, df["elapsed_min"].max())
    prepared.append((df, title))

for i, (df, title) in enumerate(prepared):
    df_new = df[df["is_new_bug"]].copy()

    if len(df_new) == 0:
        axes[i].set_title(f"{title} Crashes")
        axes[i].text(0.5, 0.5, "No unique crashes", ha="center", va="center")
        axes[i].set_xlim(0, max_elapsed)
        axes[i].grid(True)
        continue

    # Plot only the points/line where a new unique bug is discovered
    axes[i].plot(
        df_new["elapsed_min"],
        df_new["Unique Crashes"],
        marker="o",
        linestyle="-",
        label="Unique crashes"
    )

    axes[i].set_title(f"{title} Crashes")
    axes[i].set_xlabel("Minutes since fuzzing start")
    axes[i].set_ylabel("Unique Crashes")
    axes[i].set_xlim(0, max_elapsed)
    axes[i].grid(True)
    axes[i].legend()

plt.tight_layout()
plt.show()
